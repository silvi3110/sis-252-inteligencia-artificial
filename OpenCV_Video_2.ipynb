# %% [markdown]
# <a href="https://colab.research.google.com/github/silvi3110/sis-252-inteligencia-artificial/blob/main/OpenCV_Video_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python opencv-python-headless

import cv2
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('Gente caminando.mp4')
fgbg = cv2.createBackgroundSubtractorMOG2()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_resized = cv2.resize(frame, (640, 480))
    fgmask = fgbg.apply(frame_resized)

    cv2_imshow(fgmask)

cap.release()
cv2.destroyAllWindows()
